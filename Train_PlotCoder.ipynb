# %% [markdown]
# <a href="https://colab.research.google.com/github/hongnhungocvn99/1712105/blob/master/Train_PlotCoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/Train_plotcoder/plotcoder
# Out:
# /content/drive/MyDrive/Train_plotcoder/plotcoder

# %%
ls
# Out:
# arguments.py  models/       plot_sample_extraction.py  requirements.txt
# LICENSE       Pipfile       __pycache__/               run.py
# log.json      Pipfile.lock  README.md

# %%
pip install ast2json

# %%
# !python plot_sample_extraction.py
# Out:
# preprocessing training data:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/json/decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "plot_sample_extraction.py", line 183, in <module>
#     train_plot_samples, train_plot_clean_samples = preprocess(args.data_folder, args.init_train_data_name, args.prep_train_data_name, is_train=True)
#   File "plot_sample_extraction.py", line 65, in preprocess
#     sample = json.loads(line)
#   File "/usr/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.7/json/decoder.py", line 354, in raw_decode
#     except StopIteration as err:
# KeyboardInterrupt

# %%
# !python run.py --nl --use_comments --code_context --nl_code_linking --copy_mechanism --hierarchy --target_code_transform
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# batch_idx:  192 test_label_acc:  162 test_data_acc 72 test_acc 59
# batch_idx:  256 test_label_acc:  207 test_data_acc 92 test_acc 75
# batch_idx:  320 test_label_acc:  244 test_data_acc 111 test_acc 90
# batch_idx:  384 test_label_acc:  295 test_data_acc 123 test_acc 102
# batch_idx:  448 test_label_acc:  337 test_data_acc 145 test_acc 118
# batch_idx:  512 test_label_acc:  385 test_data_acc 165 test_acc 133
# batch_idx:  576 test_label_acc:  430 test_data_acc 182 test_acc 150
# batch_idx:  640 test_label_acc:  467 test_data_acc 196 test_acc 161
# batch_idx:  704 test_label_acc:  506 test_data_acc 217 test_acc 175
# batch_idx:  768 test_label_acc:  546 test_data_acc 230 test_acc 185
# global-step: 1840, train-acc: 0.956, train-loss: 1.049, eval-label-acc: 0.660, eval-data-acc: 0.278, eval-acc: 0.224, eval-loss: 193569518.646
# 3 640
# train loss: 0.8223 train acc: 0.9466
# 3 704
# train loss: 0.8673 train acc: 0.9408
# ...

# %%
# !cudnn
# Out:
# /bin/bash: cudnn: command not found

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.
